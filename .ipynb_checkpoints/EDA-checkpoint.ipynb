# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
# Display the first few rows of the dataset
print("Train Data:")
print(train_data.head())
print("\nTest Data:")
print(test_data.head())

# Summary statistics
print("\nTrain Data Summary:")
print(train_data.describe(include='all'))
print("\nTest Data Summary:")
print(test_data.describe(include='all'))

# Check for missing values
print("\nMissing Values in Train Data:")
print(train_data.isnull().sum())
print("\nMissing Values in Test Data:")
print(test_data.isnull().sum())

# Data types of each column
print("\nData Types in Train Data:")
print(train_data.dtypes)
print("\nData Types in Test Data:")
print(test_data.dtypes)
# Out:
# Train Data:
#          Date_Time   Sex         Nation        Job Freelance_Status  \
# 0  8/27/2014 13:47  Male  United States   Business               No
# 1  8/29/2014 14:31  Male  United States    Student              Yes
# 2  8/27/2014 11:34  Male             US     Others              NaN
# 3  8/28/2014 22:22  Male  United States  Housewife               No
# 4  8/27/2014 14:53  Male  United States  Housewife               No
#
#   Genetic_Background Therapy         Indoor_Days Increasing_Stress  \
# 0                 No      No          15-30 days             Maybe
# 1                Yes     Yes           1-14 days             Maybe
# 2                 No     Yes  More than 2 months                No
# 3                 No     Yes          15-30 days             Maybe
# 4                 No     Yes    Go out Every day               Yes
#
#   Habit_Changes Psychological_History Emotional_Fluctuations  \
# 0         Maybe                    No                 Medium
# 1           Yes                    No                   High
# 2            No                    No                   High
# 3            No                    No                    Low
# 4           Yes                    No                    Low
#
#   Adaptation_Challenges Job_Engagement Social_Vulnerability Psych_Evaluation  \
# 0                   Yes          Maybe                  Yes               No
# 1                    No            Yes                Maybe               No
# 2                    No            Yes                   No               No
# 3                   Yes          Maybe                  Yes               No
# 4                   Yes             No                   No               No
#
#   Support_Options  Body_Weight
# 0             Yes         59.0
# 1        Not sure         58.0
# 2             Yes         70.0
# 3              No         72.0
# 4             Yes         94.0
#
# Test Data:
#    ID        Date_Time     Sex         Nation        Job Freelance_Status  \
# 0   1  8/27/2014 13:31  Female         Canada  Corporate               No
# 1   2  8/27/2014 14:13  Female  United States  Corporate               No
# 2   3  8/27/2014 16:25  Female  United States  Corporate              Yes
# 3   4  8/27/2014 16:42  Female  United States  Corporate               No
# 4   5  8/29/2014 21:40  Female         Canada  Corporate              Yes
#
#   Genetic_Background Therapy Indoor_Days Increasing_Stress Habit_Changes  \
# 0                Yes     Yes   1-14 days               Yes            No
# 1                Yes     Yes   1-14 days               Yes            No
# 2                Yes     Yes   1-14 days               Yes            No
# 3                 No     Yes   1-14 days               Yes            No
# 4                Yes     Yes   1-14 days               Yes            No
#
#   Psychological_History Adaptation_Challenges Job_Engagement  \
# 0                   Yes                    No             No
# 1                   Yes                    No             No
# 2                   Yes                    No             No
# 3                   Yes                    No             No
# 4                   Yes                    No             No
#
#   Social_Vulnerability Psych_Evaluation Support_Options  Body_Weight
# 0                  Yes               No             Yes           74
# 1                  Yes               No             Yes           71
# 2                  Yes               No              No           64
# 3                  Yes               No             Yes           58
# 4                  Yes               No             Yes           89
#
# Train Data Summary:
#               Date_Time     Sex         Nation        Job Freelance_Status  \
# count            277746  277746         277745     277746           272781
# unique              580       2             44          6                5
# top     8/27/2014 11:43    Male  United States  Housewife               No
# freq               2269  227858         162813      62985           245078
# mean                NaN     NaN            NaN        NaN              NaN
# std                 NaN     NaN            NaN        NaN              NaN
# min                 NaN     NaN            NaN        NaN              NaN
# 25%                 NaN     NaN            NaN        NaN              NaN
# 50%                 NaN     NaN            NaN        NaN              NaN
# 75%                 NaN     NaN            NaN        NaN              NaN
# max                 NaN     NaN            NaN        NaN              NaN
#
#        Genetic_Background Therapy Indoor_Days Increasing_Stress Habit_Changes  \
# count              277746  277745      277743            277746        277746
# unique                  7       4           6                 3             4
# top                    No     Yes   1-14 days             Maybe           Yes
# freq               167960  140240       60418             95088        104110
# mean                  NaN     NaN         NaN               NaN           NaN
# std                   NaN     NaN         NaN               NaN           NaN
# min                   NaN     NaN         NaN               NaN           NaN
# 25%                   NaN     NaN         NaN               NaN           NaN
# 50%                   NaN     NaN         NaN               NaN           NaN
# 75%                   NaN     NaN         NaN               NaN           NaN
# max                   NaN     NaN         NaN               NaN           NaN
#
#        Psychological_History Emotional_Fluctuations Adaptation_Challenges  \
# count                 277744                 277746                277745
# unique                     3                      3                     4
# top                       No                 Medium                    No
# freq                   98883                  96007                146552
# mean                     NaN                    NaN                   NaN
# std                      NaN                    NaN                   NaN
# min                      NaN                    NaN                   NaN
# 25%                      NaN                    NaN                   NaN
# 50%                      NaN                    NaN                   NaN
# 75%                      NaN                    NaN                   NaN
# max                      NaN                    NaN                   NaN
#
#        Job_Engagement Social_Vulnerability Psych_Evaluation Support_Options  \
# count          277742               277746           277744          277742
# unique              6                    3                4               5
# top                No                Maybe               No              No
# freq           100521                98197           220520          112981
# mean              NaN                  NaN              NaN             NaN
# std               NaN                  NaN              NaN             NaN
# min               NaN                  NaN              NaN             NaN
# 25%               NaN                  NaN              NaN             NaN
# 50%               NaN                  NaN              NaN             NaN
# 75%               NaN                  NaN              NaN             NaN
# max               NaN                  NaN              NaN             NaN
#
#           Body_Weight
# count   277745.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        74.933777
# std         14.710990
# min         50.000000
# 25%         62.000000
# 50%         75.000000
# 75%         88.000000
# max        100.000000
#
# Test Data Summary:
#                   ID        Date_Time    Sex         Nation        Job  \
# count   14618.000000            14618  14618          14618      14618
# unique           NaN              580      2             35          5
# top              NaN  8/27/2014 12:31   Male  United States  Housewife
# freq             NaN              129  11992           8482       3366
# mean     7309.500000              NaN    NaN            NaN        NaN
# std      4219.997453              NaN    NaN            NaN        NaN
# min         1.000000              NaN    NaN            NaN        NaN
# 25%      3655.250000              NaN    NaN            NaN        NaN
# 50%      7309.500000              NaN    NaN            NaN        NaN
# 75%     10963.750000              NaN    NaN            NaN        NaN
# max     14618.000000              NaN    NaN            NaN        NaN
#
#        Freelance_Status Genetic_Background Therapy Indoor_Days  \
# count             14381              14618   14618       14618
# unique                2                  2       2           5
# top                  No                 No     Yes   1-14 days
# freq              12914               8866    7364        3128
# mean                NaN                NaN     NaN         NaN
# std                 NaN                NaN     NaN         NaN
# min                 NaN                NaN     NaN         NaN
# 25%                 NaN                NaN     NaN         NaN
# 50%                 NaN                NaN     NaN         NaN
# 75%                 NaN                NaN     NaN         NaN
# max                 NaN                NaN     NaN         NaN
#
#        Increasing_Stress Habit_Changes Psychological_History  \
# count              14618         14618                 14618
# unique                 3             3                     3
# top                  Yes           Yes                    No
# freq                5031          5412                  5133
# mean                 NaN           NaN                   NaN
# std                  NaN           NaN                   NaN
# min                  NaN           NaN                   NaN
# 25%                  NaN           NaN                   NaN
# 50%                  NaN           NaN                   NaN
# 75%                  NaN           NaN                   NaN
# max                  NaN           NaN                   NaN
#
#        Adaptation_Challenges Job_Engagement Social_Vulnerability  \
# count                  14618          14618                14618
# unique                     2              3                    3
# top                       No             No                Maybe
# freq                    7773           5315                 5196
# mean                     NaN            NaN                  NaN
# std                      NaN            NaN                  NaN
# min                      NaN            NaN                  NaN
# 25%                      NaN            NaN                  NaN
# 50%                      NaN            NaN                  NaN
# 75%                      NaN            NaN                  NaN
# max                      NaN            NaN                  NaN
#
#        Psych_Evaluation Support_Options   Body_Weight
# count             14618           14618  14618.000000
# unique                3               3           NaN
# top                  No              No           NaN
# freq              11643            5901           NaN
# mean                NaN             NaN     74.981803
# std                 NaN             NaN     14.693450
# min                 NaN             NaN     50.000000
# 25%                 NaN             NaN     62.000000
# 50%                 NaN             NaN     75.000000
# 75%                 NaN             NaN     88.000000
# max                 NaN             NaN    100.000000
#
# Missing Values in Train Data:
# Date_Time                    0
# Sex                          0
# Nation                       1
# Job                          0
# Freelance_Status          4965
# Genetic_Background           0
# Therapy                      1
# Indoor_Days                  3
# Increasing_Stress            0
# Habit_Changes                0
# Psychological_History        2
# Emotional_Fluctuations       0
# Adaptation_Challenges        1
# Job_Engagement               4
# Social_Vulnerability         0
# Psych_Evaluation             2
# Support_Options              4
# Body_Weight                  1
# dtype: int64
#
# Missing Values in Test Data:
# ID                         0
# Date_Time                  0
# Sex                        0
# Nation                     0
# Job                        0
# Freelance_Status         237
# Genetic_Background         0
# Therapy                    0
# Indoor_Days                0
# Increasing_Stress          0
# Habit_Changes              0
# Psychological_History      0
# Adaptation_Challenges      0
# Job_Engagement             0
# Social_Vulnerability       0
# Psych_Evaluation           0
# Support_Options            0
# Body_Weight                0
# dtype: int64
#
# Data Types in Train Data:
# Date_Time                  object
# Sex                        object
# Nation                     object
# Job                        object
# Freelance_Status           object
# Genetic_Background         object
# Therapy                    object
# Indoor_Days                object
# Increasing_Stress          object
# Habit_Changes              object
# Psychological_History      object
# Emotional_Fluctuations     object
# Adaptation_Challenges      object
# Job_Engagement             object
# Social_Vulnerability       object
# Psych_Evaluation           object
# Support_Options            object
# Body_Weight               float64
# dtype: object
#
# Data Types in Test Data:
# ID                        int64
# Date_Time                object
# Sex                      object
# Nation                   object
# Job                      object
# Freelance_Status         object
# Genetic_Background       object
# Therapy                  object
# Indoor_Days              object
# Increasing_Stress        object
# Habit_Changes            object
# Psychological_History    object
# Adaptation_Challenges    object
# Job_Engagement           object
# Social_Vulnerability     object
# Psych_Evaluation         object
# Support_Options          object
# Body_Weight               int64
# dtype: object

# %%
def fill_missing_values(df):
    for column in df.columns:
        if df[column].dtype == 'object':
            # Fill missing categorical values with the mode
            df[column].fillna(df[column].mode()[0], inplace=True)
        else:
            # Fill missing numerical values with the mean
            df[column].fillna(df[column].mean(), inplace=True)
    return df

train_data = fill_missing_values(train_data)
test_data = fill_missing_values(test_data)

# %%
categorical_columns = ['Sex', 'Nation', 'Job', 'Freelance_Status', 'Genetic_Background', 
                       'Therapy', 'Indoor_Days', 'Increasing_Stress', 'Habit_Changes', 
                       'Psychological_History', 'Adaptation_Challenges', 'Job_Engagement', 
                       'Social_Vulnerability', 'Psych_Evaluation', 'Support_Options', 'Emotional_Fluctuations']

for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=train_data, x=col, order=train_data[col].value_counts().index)
    plt.xticks(rotation=90)
    plt.title(f'Countplot of {col}')
    plt.show()

# %%
numerical_columns = ['Body_Weight']

for col in numerical_columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(train_data[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
# Plot pairplot for numerical columns
sns.pairplot(train_data[numerical_columns + ['Emotional_Fluctuations']], hue='Emotional_Fluctuations')
plt.show()
# Out:
# C:\Users\tehre\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for col in numerical_columns:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Emotional_Fluctuations', y=col, data=train_data)
    plt.title(f'Boxplot of {col} by Emotional_Fluctuations')
    plt.show()
